# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from data_loader import get_loader_oxford

# %%
data_loader = get_loader_oxford(
    './data/oxford/images',
    './data/oxford/annotations/cond_tab_training.csv',
    ['Ragdoll', 'Persian', 'Bengal', 'British_Shorthair', 'Russian_Blue'],
    batch_size=1
)
# Out:
# Finished preprocessing the Oxford Cat dataset

# %%
data_iter = iter(data_loader)
images, conds = next(data_iter)

# %%
images.shape
# Out:
# torch.Size([1, 3, 128, 128])

# %%
conds
# Out:
# tensor([[[0., 1., 0., 0., 0.]]])

# %%
import numpy as np

# %%
img_v = np.squeeze(images.numpy()).transpose(1, 2, 0) * 0.5 + 0.5
img_v.shape
# Out:
# (128, 128, 3)

# %%
plt.imshow(img_v)

# %%
for i in range(20):
    images, _ = next(data_iter)
    img_v = np.squeeze(images.numpy()).transpose(1, 2, 0) * 0.5 + 0.5
    plt.imshow(img_v)
    plt.show()

# %% [markdown]
# 結構猫がちゃんと写り込まないケースが多い…
